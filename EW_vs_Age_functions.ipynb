# %%
import os
os.chdir('/cluster/medbow/project/phangs/tjuchau/') #TJ change working directory to be the parent directory
from Py_files.Functions import *
image_files, filter_files = collect_M51_image_and_filter_files(filter_directory, image_directory)
import re
from astropy.table import Table
import numpy as np

M51_pa_alpha_file = [x for x in image_files if extract_filter_name(x) == 'F187N'][0]
M51_cont_files = [x for x in image_files if extract_filter_name(x) in ['F150W', "F300M"]]

def get_EW_using_filters(feature_filter_file, continuum_filter_files, location, radius):
    #TJ load files

    #TJ get all 3 image fluxes
    Fnu_feature = get_image_flux(feature_filter_file, location, radius, replace_negatives=False)
    Fnu_cont = [get_image_flux(f, location, radius, replace_negatives=False) for f in continuum_filter_files]
    feature_filter = extract_filter_name(feature_filter_file)
    continuum_filters = [extract_filter_name(x) for x in continuum_filter_files]
    if Fnu_feature.unit != Fnu_cont[0].unit:
        print('units are not the same in the feature image and continuum image!')
    elif Fnu_feature.unit == u.W/(u.m**2*u.Hz):
            
        #TJ look up pivot wavelengths
        pivot_feat = jwst_pivots[feature_filter]
        pivot_cont = [jwst_pivots[extract_filter_name(f)] for f in continuum_filter_files]
        
        #TJ convert continuum levels into F_lambda using pivot wavelengths, still need to multiply by dlamda
        fλ_cont = [(Fnu * c / pivot**2).to(u.W / u.m**2 / u.m)
                   for Fnu, pivot in zip(Fnu_cont, pivot_cont)]
        
        #TJ get mean wavelengths
        cont_wls = [jwst_means[f] for f in continuum_filters]
        line_wl = jwst_means[feature_filter]
    
        #TJ interpolate continuum values to the feature wavelength
        feature_continuum = np.interp(
            line_wl.value,
            [w.value for w in cont_wls],
            [f.value for f in fλ_cont]
        ) * u.W / u.m**2 / u.m
        
        #TJ print continuum if needed
        #print("F_lamda of photo continuum : ", feature_continuum)
        #TJ get filter transmission curve info
        wl, T = get_filter_data(feature_filter)
    
        #TJ multiply feature F_lambda by dlambda to complete unit conversion
        norm = np.trapz(T, wl) / np.max(T)
        cont_in_filter = feature_continuum * norm
        
        #TJ convert feature filter's F_nu into F_lamda
        fλ_feature = ((Fnu_feature * c / pivot_feat**2).to(u.W / u.m**2 / u.m))*norm 
    
        #TJ feature area is only the area above the continuum
        feature_only = fλ_feature - cont_in_filter
    
        #TJEquivalent width is this area divided by the continuum level
        EW = (feature_only / feature_continuum).to(u.m)
    
        return EW
        
    elif Fnu_feature.unit == u.W/u.m**2:
        print('test')

def get_Pa_a_continuum(continuum_filter_files, location, radius):

    #TJ get the two image fluxes
    app_sum = [get_image_flux(f, location, radius, replace_negatives=False) for f in continuum_filter_files]
    continuum_filters = [extract_filter_name(x) for x in continuum_filter_files]
    if app_sum[0].unit != app_sum[1].unit:
        print('units are not the same in the two images!')
        
    elif app_sum[0].unit == u.W/(u.m**2*u.Hz):
        #TJ look up pivot wavelengths
        pivot_feat = jwst_pivots['F187N']
        pivot_cont = [jwst_pivots[extract_filter_name(f)] for f in continuum_filter_files]
        
        #TJ convert continuum levels into F_lambda using pivot wavelengths, still need to multiply by dlamda
        fλ_cont = [(Fnu * c / pivot**2).to(u.W / u.m**2 / u.m)
                   for Fnu, pivot in zip(app_sum, pivot_cont)]

    elif app_sum[0].unit == u.W/u.m**2:
        fλ_cont = []
    
        for Fband, filt in zip(app_sum, continuum_filters):

            wl, T = get_filter_data(filt)

            width = np.trapz(T, wl)  # effective width

            fλ = (Fband / width).to(u.W/u.m**2/u.m)

            fλ_cont.append(fλ)
    #TJ interpolate continuum values to the feature wavelength
    feature_continuum = np.interp(
        pivot_feat.value,
        [w.value for w in pivot_cont],
        [f.value for f in fλ_cont]
    ) * u.W / u.m**2 / u.m
    
    #TJ print continuum if needed
    #print("F_lamda of photo continuum : ", feature_continuum)
    #TJ get filter transmission curve info
    wl, T = get_filter_data("F187N")

    #TJ multiply feature F_lambda by dlambda to complete unit conversion
    norm = np.trapz(T, wl) / np.max(T)
    cont_in_filter = feature_continuum * norm
    return cont_in_filter

def get_filter_Weff(filter_name):
    wl, T = get_filter_data(filter_name)
    return np.trapz(T,wl) / np.max(T)
        
        
def get_galaxy_ID_from_file(file):
    try:
        gal = file.split('/')[-1].split('_')[0]
        return gal
    except:
        return None

# %%
from astropy.table import Table
from astropy.coordinates import SkyCoord
import astropy.units as u
import glob

# -------------------------------------------------
# Gather file info per galaxy
# -------------------------------------------------
kiana_files = glob.glob('Data_files/Kiana_Cluster_Files/*nircam_all_clusters_results.csv')
radius = 0.3*u.arcsec
data = {}

for file in kiana_files:
    name = get_galaxy_ID_from_file(file)
    data.setdefault(name, {})
    data[name]['files'] = {}

# Danny files (images etc.)
danny_files = glob.glob('/d/crow2/phangs/cycle*/**/*', recursive=True)

for file in danny_files:
    name = get_galaxy_ID_from_file(file)

    if name not in data:
        continue

    if ("f187n_continuum.fits" in file) or ('paa_native_anchor_cont.fits' in file):
        data[name]['files']['F187N_continuum'] = file

    elif ('f187n_line.fits' in file) or ('paa_native_anchor_line.fits' in file):
        data[name]['files']['F187N_line'] = file

    elif extract_filter_name(file) == "F300M":
        data[name]['files']["F300M"] = file

    elif extract_filter_name(file) == "F150W":
        data[name]['files']["F150W"] = file
    elif "f187n_i2d_anchor" in file:
        data[name]['files']["F187N"] = file


galaxy_tables = {}

for file in kiana_files:

    name = get_galaxy_ID_from_file(file)

    # Require needed Pa-alpha files
    if 'F187N' not in data[name]['files']:
        continue

    t = Table.read(file, format="csv")

    locations = []
    ages = []
    stellar_masses = []
    gas_masses = []
    Avs = []
    EWs = []
    mass = []
    for row in t:
        
        loc = SkyCoord(ra=row['ra']*u.deg,
                       dec=row['dec']*u.deg)

        EW = get_EW_using_filters(data[name]['files']['F187N'], [data[name]['files']['F150W'], data[name]['files']['F300M']], loc, radius)
        
        # --- Append ---
        locations.append(loc)
        ages.append(row['best.sfh.age'])
        stellar_masses.append(row['best.stellar.m_star'])
        gas_masses.append(row['best.stellar.m_gas'])
        Avs.append(row['best.attenuation.A550'])
        EWs.append(EW.to(u.AA))
        mass.append(row['best.stellar.m_star'] + row['best.stellar.m_gas'])
    # --- Create Table ---
    tab = Table()
    tab['location'] = locations
    tab['age_Myr'] = ages
    tab['stellar_mass_Msun'] = stellar_masses
    tab['gas_mass_Msun'] = gas_masses
    tab['Av'] = Avs
    tab['PaA_EW'] = EWs
    tab['mass'] = mass
    galaxy_tables[name] = tab


# -------------------------------------------------
# Optional: list galaxies with full data
# -------------------------------------------------
full_data = list(galaxy_tables.keys())

# %%
mass_cuts = [1000, 5000, 15000, 50000, 150000, 500000, 1500000, 5000000]
young = galaxy_tables['ngc1433'][galaxy_tables['ngc1433']['age_Myr'] < 20]
galaxy_tables['ngc1433'].sort('mass')
m1 = galaxy_tables['ngc1433'][galaxy_tables['ngc1433']['mass'] < mass_cuts[0]]
m5 = galaxy_tables['ngc1433'][(galaxy_tables['ngc1433']['mass'] < mass_cuts[1]) & (galaxy_tables['ngc1433']['mass'] > mass_cuts[0])]
m10 = galaxy_tables['ngc1433'][(galaxy_tables['ngc1433']['mass'] < mass_cuts[2]) & (galaxy_tables['ngc1433']['mass'] > mass_cuts[1])]
m50 = galaxy_tables['ngc1433'][(galaxy_tables['ngc1433']['mass'] < mass_cuts[3]) & (galaxy_tables['ngc1433']['mass'] > mass_cuts[2])]
m100 = galaxy_tables['ngc1433'][(galaxy_tables['ngc1433']['mass'] < mass_cuts[4]) & (galaxy_tables['ngc1433']['mass'] > mass_cuts[3])]
m500 = galaxy_tables['ngc1433'][(galaxy_tables['ngc1433']['mass'] < mass_cuts[5]) & (galaxy_tables['ngc1433']['mass'] > mass_cuts[4])]
m1000 = galaxy_tables['ngc1433'][(galaxy_tables['ngc1433']['mass'] < mass_cuts[6]) & (galaxy_tables['ngc1433']['mass'] > mass_cuts[5])]
m5000 = galaxy_tables['ngc1433'][(galaxy_tables['ngc1433']['mass'] < mass_cuts[7]) & (galaxy_tables['ngc1433']['mass'] > mass_cuts[6])]
mass_sets = [m1, m5, m10, m50, m100, m500, m1000, m5000]
for set in mass_sets:
    print(len(set))
    print(np.mean(set['mass']))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 2
#       1 mass_cuts = [1000, 5000, 15000, 50000, 150000, 500000, 1500000, 5000000]
# ----> 2 young = galaxy_tables['ngc1433'][galaxy_tables['ngc1433']['age_Myr'] < 20]
#       3 galaxy_tables['ngc1433'].sort('mass')
#       4 m1 = galaxy_tables['ngc1433'][galaxy_tables['ngc1433']['mass'] < mass_cuts[0]]
#
# KeyError: 'ngc1433'

# %%
data
# Out:
# {}

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('/project/phangs/tjuchau/slug2')  # Path to slug2 directory


import os
home_directory = "/project/phangs/tjuchau/" 
os.chdir(home_directory) #TJ change working directory to be the parent directory
from Py_files.Basic_analysis import *

import glob
import re
slug_path = "/project/phangs/tjuchau/slug2/bin/slug"
os.chdir("/project/phangs/tjuchau/slug2")
import slugpy
wd = '/project/phangs/tjuchau'


def try_float(x):
    '''
    Try to convert an item or an array of items to float.
    If conversion fails, returns original value(s).
    
    Parameters
    ----------
    x : scalar or array-like
        Item(s) to convert.
    
    Returns
    -------
    float, array of floats, or original input if conversion fails.
    '''
    # If x is array-like, attempt vectorized conversion
    if isinstance(x, (list, np.ndarray)):
        try:
            return np.array(x, dtype=float)
        except ValueError:
            return x
    else:
        # Scalar input
        try:
            return float(x)
        except ValueError:
            return x
            
def do_alex_model(model_name, mass, N=1000):
    '''Replication of Alex's model'''
    input_file = f"{model_name}.slugin"
    
    with open(input_file, 'w') as f:
        f.write(f'model_name {model_name}\n')
        f.write(f'out_dir /project/phangs/tjuchau/Data_files/Misc_data/Slug_outputs\n') #TJ this is where the output files will be written to
        f.write(f'verbosity 1\n') #TJ level of printed outputs while running (0=only warnings/errors) (1=some outputs) (2=lots of outputs)
        ##################################################################
        # Parameters controlling simulation execution and physical model #
        ##################################################################
        f.write(f'sim_type cluster\n') #TJ must be either galaxy or cluster (defaults to galaxy)
        f.write(f'n_trials {N}\n') #TJ total number of model clusters to run
        #f.write(f'checkpoint_interval = 100\n') #TJ create checkpoint after this many trials (default to no checkpointing)
        f.write(f'time_step 1.0e6\n') #TJ simulation runs for 1million years before computing new values
        #f.write(f'start_time 1.0e6\n') #TJ default start time is the same as timestep
        f.write(f'end_time 1.0e7\n') #TJ how long does each simulation run for in years
        #f.write(f'sfr 0.001\n') #TJ star formation rate, ignored for sim types = cluster
        #f.write(f'sfh sfh.txt\n') #TJ star formation history, ignored for sim types = cluster
        f.write(f'cluster_mass {mass}\n') #TJ cluster mass in solar masses, ignored for sim type = galaxy
        #f.write(f'redshift 0\n') #TJ defaults to 0
        ##################################################################
        # Parameters controlling simulation outputs #
        ##################################################################
        f.write(f'out_cluster 1\n') #TJ output cluster properties? default = 1
        f.write(f'out_cluster_phot 1\n') #TJ output cluster photometry? (must specify filters also)
        f.write(f'out_cluster_spec 0\n') #TJ output cluster spectroscopy? *adds significant computation time*
        f.write(f'out_cluster_yield 1\n') #TJ output cluster nucleosynthesis yields?
        #f.write(f'out_integrated 1\n') #TJ output integrated properties of galaxy? ignored for sim types = cluster
        #f.write(f'out_integrated_phot 1\n') #TJ output integrated photometry of galaxy? ignored for sim types = cluster
        #f.write(f'out_integrated_spec 1\n') #TJ output integrated spectroscopy of galaxy? ignored for sim types = cluster
        #f.write(f'out_integrated_yield 1\n') #TJ output integrated chemical yields of galaxy? ignored for sim types = cluster
        f.write(f'output_mode ascii\n') #TJ can be either binary, ascii, or fits
        #####################################################################
        # Parameters controlling the physical models used for stars         #
        #####################################################################
        #f.write(f'imf lib/imf/chabrier.imf\n') #TJ what imf to use? defaults to chabrier 2001
        #f.write(f'cmf lib/cmf/slug_default.cmf\n') #TJ cluster mass function for galaxies, ignored for sim types = cluster
        f.write(f'clf lib/clf/nodisrupt.clf\n') #TJ cluster lifetime Default: lib/clf/slug_default.clf (dN/dt ~ t^-1.9)
        f.write(f'tracks mist_2016_vvcrit_40\n') #TJ choose the stellar track. Defaults to geneva_2013_vvcrit_00
        f.write(f'atmospheres lib/atmospheres\n') #TJ directory of the stellar atmospheres
        f.write(f'specsyn_mode sb99\n') #TJ Spectral synthesis mode, describing which models to use for stellar atmospheres allowed values below
        # -- planck (treat stars as blackbodies)
        # -- kurucz (use Kurucz atmospheres, as compiled by Lejeune+ 1997)
        # -- kurucz+hillier (use Hillier models for WR stars, kurucz for all others)
        # -- kurucz+pauldrach (use Pauldrach models for OB stars, kurucz for others)
        # -- sb99 (emulate starburst99 -- Pauldrach for OB stars, Hillier for WR stars, kurucz for others) This is the default value
        f.write(f'clust_frac 1.0\n') #TJ fraction of stars born in clusters (always 1.0 for sim types = cluster)
        f.write(f'min_stoch_mass 0.08\n') #TJ minimum stochastically sampled mass. Everything below is considered to be continuously sampled
        #f.write(f'metallicity       1.0\n') #TJ metalicity function. If tracks is specified, this should be omitted
        #####################################################################
        # Parameters controlling extinction                                 #
        #####################################################################
        f.write(f'A_V lib/avdist/slug_default.av\n') #TJ set extinction function
        f.write(f'extinction_curve lib/extinct/MW_EXT_SLUG.dat\n') #TJ shape of extinction curve
        f.write(f'nebular_extinction_factor lib/avdist/neb_factor_default.av\n') #TJ use a different extinction law for nebulae
        #####################################################################
        # Parameters controlling nebular emission                           #
        #####################################################################
        f.write(f'compute_nebular 1\n') #TJ compute nebular emission specifically?
        #f.write(f'atomic_data lib/atomic\n') #TJ atomic information, defaults to lib/atomic
        #f.write(f'nebular_no_metals 0\n') #TJ 1 would be to turn off nebular metal emission (includes He), 0 means leave metals on
        #f.write(f'nebular_den 1.0e2\n') #TJ hydrogen density (default is 100)
        #f.write(f'nebular_temp -1.0\n') #TJ nebular temperature, default is -1, if negative, temp will be calculated from cloudy
        f.write(f'nebular_logU -2.5\n') #TJ logU representing ionization parameter
        f.write(f'nebular_phi 0.73\n') #TJ fraction of ionizing photons that are absorbed by Hydrogen atoms
        #############################################
        # Parameters describing photometric filters #
        #############################################
        f.write(f'phot_bands JWST_F150W, JWST_F187N, JWST_F300M\n') #TJ list of filters for photometric results
        f.write(f'filters lib/filters\n') #TJ directory for filter information to be read from
        #f.write(f'phot_mode Lnu\n') #TJ what units should the photometry results print in?
        ############################################
        # Parameters controlling yield calculation #
        ############################################
        f.write(f'yield_dir lib/yields\n') #TJ directory for yield files
        
        # are available:
        # 
        
        # 
        f.write(f'yield_mode sukhbold16+karakas16+doherty14\n') #TJ Model to use for yield calculation. Currently the following models accepted:
        # -- sukhbold16 = Solar metallicity type II SN yields from Sukhbold et al. (2016, ApJ, 821, 38); no other yields
        # -- # karakas16+doherty14 = metallicity-dependent AGB star yields from Karakas & Lugaro (2016, ApJ, 825, 26), and super- 
        #                                                                                 AGB star yields from Doherty+ (2014, MNRAS, 437, 195)
        # -- sukhbold16+karakas16+doherty14 = sukhbold16 used for SNII, karakas16+doherty14 for AGB
        f.write(f'\n')

    return input_file


def read_all_files(model_name):
    '''
    Reads all SLUG output .txt files for a given model_name into a dictionary of numpy arrays.
    Keys are column names, values are data arrays.
    '''
    output = {}
    files = glob.glob(f'/project/phangs/tjuchau/Data_files/Misc_data/Slug_outputs/*_cluster*.txt')
    
    for file in files:
        with open(file, 'r') as f:
            lines = f.readlines()
        
        # Get column names
        col_names = lines[0].strip().split()
        n_cols_names = len(col_names)
        
        # Parse data lines
        data_entries = []
        for line in lines[2:]:
            stripped = line.strip()
            if line.startswith('---------'):
                continue
            entries = stripped.split()
            
            # Pad missing entries with 'nan'
            if len(entries) < n_cols_names:
                entries += ['nan'] * (n_cols_names - len(entries))
            data_entries.append(entries)
        
        # Skip empty files gracefully
        if not data_entries:
            continue
        
        # Convert to numpy array of strings first
        data_array = np.array(data_entries, dtype='U20')
        
        # Convert each column individually to float if possible, else keep as string
        for i, name in enumerate(col_names):
            col = data_array[:, i]
            try:
                col_converted = col.astype(float)
            except ValueError:
                col_converted = col  # keep as string if conversion fails
            
            if name in output:
                print(f"Warning: Duplicate column name '{name}' found. Overwriting previous value.")
            output[name] = col_converted
    
    return output


def compute_paalpha_ew(data):  
    """  
    Compute Paα flux and equivalent width from SLUG output.  

    Args:  
        data (dict): Dictionary with filter fluxes (e.g., 'JWST_F150W').  

    Returns:  
        dict: Paα flux (Jy), continuum (Jy), and EW (Å).  
    """  
    # Extract fluxes (adjust keys if needed)  
    f150 = data['JWST_F150W']  # Continuum filter 1  
    f300 = data['JWST_F300M']  # Continuum filter 2  
    f187n = data['JWST_F187N'] # Paα filter  
    f187c = data['JWST_F187N_n'] #continuum around Paa
    # Estimate continuum at Paα (1.875 µm) by linear interpolation  
    # Wavelengths (µm) for each filter (central λ from JWST)  
    lambda150 = jwst_pivots['F150W'].to(u.um).value
    lambda187 = jwst_pivots['F187N'].to(u.um).value
    lambda300 = jwst_pivots['F300M'].to(u.um).value

    # Linear fit to continuum (F150W and F200W)  
    slope = (f300 - f150) / (lambda300 - lambda150)  
    continuum = f150 + slope * (lambda187 - lambda150)  
    
    # Subtract continuum to isolate Paα flux  
    paalpha_flux = f187n - continuum  
    paalpha_flux_c = f187n - f187c
    # Compute equivalent width (EW) in Ångströms  
    # EW = Δλ (F_line / F_continuum), where Δλ = F187N filter width (~0.02 µm = 200 Å)  
    f187n_width = 0.02 * 1e4  # Convert µm to Å (1 µm = 1e4 Å)  
    ew = f187n_width * (paalpha_flux / continuum)  
    ew_c = f187n_width * (paalpha_flux_c / f187c)  

    return {'paalpha_flux': paalpha_flux, 'continuum': continuum, 'EW': ew,
            'paalpha_flux_c': paalpha_flux, 'continuum_c': continuum, 'EW_c': ew_c}

N_array = [1000, 1000, 1000, 1000, 800, 700, 500, 250]
mass_sets = [{'mass':1e2}, {'mass':1e3}, {'mass':1e4}, {'mass':1e5}, {'mass':1e6}, {'mass':1e7}, {'mass':1e8}, {'mass':1e9},]
for i, set in enumerate(mass_sets):
    m = int(np.round(np.mean(set['mass'])))
    model_name = f'testing_young_cluster_mass_{m}'
    slug_input_file = do_alex_model(model_name, m, N=N_array[i])
    os.system(f'{slug_path} {slug_input_file}')
    temp = read_all_files(model_name)
    rows = [dict(zip(temp.keys(), values)) for values in zip(*temp.values())]
    ews = []
    ews_c = []
    for row in rows:
        ews.append(compute_paalpha_ew(row)['EW'])
        ews_c.append(compute_paalpha_ew(row)['EW_c'])
    data = np.array([temp['Time'], ews, ews_c])
    np.save(f'/d/ret1/Taylor/jupyter_notebooks/Research/SLUG_stuff/datasets/young_{m}_mass_EW.npy', data)
# Out:
# /project/phangs/tjuchau/slug2/bin/slug: error while loading shared libraries: libcfitsio.so.10: cannot open shared object file: No such file or directory
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 240
#     238     ews.append(compute_paalpha_ew(row)['EW'])
#     239     ews_c.append(compute_paalpha_ew(row)['EW_c'])
# --> 240 data = np.array([temp['Time'], ews, ews_c])
#     241 np.save(f'/d/ret1/Taylor/jupyter_notebooks/Research/SLUG_stuff/datasets/young_{m}_mass_EW.npy', data)
#
# KeyError: 'Time'

# %%
# Out:
# /apps/u/opt/linux/miniconda3/24.3.0/condabin/conda
# 0

# %%
# Determine grid size (e.g. 2 rows x 3 columns for 6 plots)
n_cols = 4
n_rows = int(np.ceil(len(mass_sets) / n_cols))

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 8), sharex=True, sharey=True)
axes = axes.flatten()

for i, set in enumerate(mass_sets[:-1]):
    m = np.round(np.mean(set['mass']))
    data = np.load(f'/d/ret1/Taylor/jupyter_notebooks/Research/SLUG_stuff/datasets/young_{m}_mass_EW.npy')
    
    ax = axes[i]
    chunk_data = []
    c_chunk_data = []
    for chunk in range(1000):
        start = 10*chunk
        ax.plot(data[0][start:start+10], data[1][start:start+10], linewidth = 0.1, color = 'black')
        chunk_data.append(data[1][start:start+10])
        c_chunk_data.append(data[2][start:start+10])
        
    chunk_data = np.array(chunk_data)  # shape: (100, 10)
    c_chunk_data = np.array(chunk_data)  # shape: (100, 10)
    
    # Calculate median across chunks for each timestep
    median_y = np.nanmedian(chunk_data, axis=0)
    median_y_c = np.nanmedian(c_chunk_data, axis=0)
    
    # Overplot median track
    ax.plot(data[0][start:start+10], median_y_c, color='blue', linewidth=2, label='Median_c')
    ax.scatter(set['age_Myr']*1e6, set['PaA_EW'], color = 'red')
    ax.set_title(f'Mass = {m}')
    ax.set_xlabel('Age (years)')
    ax.set_ylabel('EW in Angstroms')
    ax.legend(fontsize=6)
    ax.set_xscale('log')
    ax.set_xlim([1e6,5e7])
    ax.set_ylim([1e0,5e4])
    ax.set_yscale('log')
# Hide any unused subplots
for j in range(i+1, len(axes)):
    axes[j].set_visible(False)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 21
#      18     chunk_data.append(data[1][start:start+10])
#      19     c_chunk_data.append(data[2][start:start+10])
# ---> 21 chunk_data = np.array(chunk_data)  # shape: (100, 10)
#      22 c_chunk_data = np.array(chunk_data)  # shape: (100, 10)
#      24 # Calculate median across chunks for each timestep
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (1000,) + inhomogeneous part.

# %%
test = data['ngc1433']
loc = test['region_1']['location']
radius = 0.3*u.arcsec
files = [test['files'][x] for x in test['files']]
show_images(files, loc, radius)
for file in files:
    print(get_image_flux(file, loc, radius))
get_image_flux(image_files[0], locations[0], radius)
# Out:
# 7.699738677828699e-20 W / m2
# -6.979074518411729e-20 W / m2
# 3.8282553138645e-32 W / (Hz m2)
# 1.995748705902228e-32 W / (Hz m2)
# <Quantity 4.65998259e-31 W / (Hz m2)>

# %%
for i in range(173):
    print('Region ',i)
    loc = test[f'region_{i}']['location']
    print('continuum flux : ', get_image_flux(test['files']['F187N_continuum'], loc, radius))
    print('Predicted continuum : ', get_Pa_a_continuum([test['files']['F150W'], test['files']['F300M']], loc, radius))
    print('line flux : ', get_image_flux(test['files']['F187N_line'], loc, radius))
# Out:
# Region  0
# continuum flux :  7.699738677828699e-20 W / m2
# Predicted continuum :  9.430858147555919e-20 W / m2
# line flux :  -6.979074518411729e-20 W / m2
# Region  1
# continuum flux :  1.0192800120749968e-19 W / m2
# Predicted continuum :  1.3185046424311844e-19 W / m2
# line flux :  -5.59835343677443e-20 W / m2
# Region  2
# continuum flux :  1.3006758859419494e-19 W / m2
# Predicted continuum :  1.6894429430741907e-19 W / m2
# line flux :  -3.144357593602301e-20 W / m2
# Region  3
# continuum flux :  9.284258743117572e-20 W / m2
# Predicted continuum :  1.297592422809986e-19 W / m2
# line flux :  9.368753821786432e-21 W / m2
# Region  4
# continuum flux :  7.40295805266614e-20 W / m2
# Predicted continuum :  1.0650976213647324e-19 W / m2
# line flux :  4.2623578275756424e-20 W / m2
# Region  5
# continuum flux :  9.908283642937594e-20 W / m2
# Predicted continuum :  1.3877754062841016e-19 W / m2
# line flux :  -6.853348960871809e-21 W / m2
# Region  6
# continuum flux :  1.2076067095847397e-19 W / m2
# Predicted continuum :  1.6542835276686514e-19 W / m2
# line flux :  1.2418040021995574e-20 W / m2
# Region  7
# continuum flux :  1.2699654204013423e-19 W / m2
# Predicted continuum :  1.6314713288029667e-19 W / m2
# line flux :  -3.090198314158701e-20 W / m2
# Region  8
# continuum flux :  1.294110813663332e-19 W / m2
# Predicted continuum :  1.7427890126954596e-19 W / m2
# line flux :  -8.98473947450633e-22 W / m2
# Region  9
# continuum flux :  1.192733102476821e-19 W / m2
# Predicted continuum :  1.634348353244222e-19 W / m2
# line flux :  9.337047326758658e-21 W / m2
# Region  10
# continuum flux :  1.1880359242838166e-19 W / m2
# Predicted continuum :  1.5958478931449053e-19 W / m2
# line flux :  -2.330875334910114e-21 W / m2
# Region  11
# continuum flux :  1.271969155504896e-19 W / m2
# Predicted continuum :  1.7216959252345584e-19 W / m2
# line flux :  -8.45587928460199e-21 W / m2
# Region  12
# continuum flux :  1.1558338113397347e-19 W / m2
# Predicted continuum :  1.732022968801725e-19 W / m2
# line flux :  7.989600532350705e-20 W / m2
# Region  13
# continuum flux :  1.393721389173672e-19 W / m2
# Predicted continuum :  1.9122645735983494e-19 W / m2
# line flux :  2.8892411418877304e-20 W / m2
# Region  14
# continuum flux :  nan W / m2
# Predicted continuum :  1.9961388216365844e-19 W / m2
# line flux :  nan W / m2
# Region  15
# continuum flux :  2.4044021350272134e-19 W / m2
# Predicted continuum :  3.10925586621716e-19 W / m2
# line flux :  1.1923702612814537e-20 W / m2
# Region  16
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  17
# continuum flux :  1.5669802564885865e-19 W / m2
# Predicted continuum :  2.1954810325480467e-19 W / m2
# line flux :  4.5269464880822284e-20 W / m2
# Region  18
# continuum flux :  1.4580406849294078e-19 W / m2
# Predicted continuum :  2.0306465604799012e-19 W / m2
# line flux :  3.2051733396001325e-20 W / m2
# Region  19
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  20
# continuum flux :  1.6802955839420279e-19 W / m2
# Predicted continuum :  2.2890313797185805e-19 W / m2
# line flux :  4.3152804586284657e-20 W / m2
# Region  21
# continuum flux :  2.933560164980708e-19 W / m2
# Predicted continuum :  3.9209612498347127e-19 W / m2
# line flux :  1.9633675091893078e-20 W / m2
# Region  22
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  23
# continuum flux :  2.54141538382693e-19 W / m2
# Predicted continuum :  3.381628202505893e-19 W / m2
# line flux :  5.2629683039275156e-20 W / m2
# Region  24
# continuum flux :  2.5403005334443793e-19 W / m2
# Predicted continuum :  3.3468497030240773e-19 W / m2
# line flux :  5.537645921611352e-20 W / m2
# Region  25
# continuum flux :  2.3978925464278435e-19 W / m2
# Predicted continuum :  3.3784689636339306e-19 W / m2
# line flux :  5.5732299804632954e-21 W / m2
# Region  26
# continuum flux :  2.012309775273417e-18 W / m2
# Predicted continuum :  2.501521970004362e-18 W / m2
# line flux :  7.984047249450265e-19 W / m2
# Region  27
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  28
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  29
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  30
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  31
# continuum flux :  1.0573809512388907e-18 W / m2
# Predicted continuum :  1.3017763137351688e-18 W / m2
# line flux :  2.3945828061744516e-20 W / m2
# Region  32
# continuum flux :  3.485993941671627e-18 W / m2
# Predicted continuum :  4.391975592450921e-18 W / m2
# line flux :  2.351816270628998e-19 W / m2
# Region  33
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  34
# continuum flux :  3.4564463851110277e-18 W / m2
# Predicted continuum :  4.357310683400057e-18 W / m2
# line flux :  3.268787328709591e-19 W / m2
# Region  35
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  36
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  37
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  38
# continuum flux :  1.1815201235961762e-18 W / m2
# Predicted continuum :  1.4807963200596107e-18 W / m2
# line flux :  7.668366793015246e-20 W / m2
# Region  39
# continuum flux :  2.0051746949982968e-19 W / m2
# Predicted continuum :  2.854681186908976e-19 W / m2
# line flux :  6.077335828913994e-20 W / m2
# Region  40
# continuum flux :  1.141710192186554e-18 W / m2
# Predicted continuum :  1.470485002477036e-18 W / m2
# line flux :  1.0104230997206299e-19 W / m2
# Region  41
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  42
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  43
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  44
# continuum flux :  2.62765640067267e-19 W / m2
# Predicted continuum :  3.5039041552315286e-19 W / m2
# line flux :  3.3503184166236085e-19 W / m2
# Region  45
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  46
# continuum flux :  3.347736865073767e-18 W / m2
# Predicted continuum :  4.146763592146152e-18 W / m2
# line flux :  1.7866677976440926e-19 W / m2
# Region  47
# continuum flux :  2.9644465265195435e-19 W / m2
# Predicted continuum :  3.9128687415747e-19 W / m2
# line flux :  7.099265752008032e-21 W / m2
# Region  48
# continuum flux :  5.844387036608507e-18 W / m2
# Predicted continuum :  7.230358026059675e-18 W / m2
# line flux :  2.3426931827518466e-19 W / m2
# Region  49
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  50
# continuum flux :  2.3755710244223866e-19 W / m2
# Predicted continuum :  3.268308685504575e-19 W / m2
# line flux :  4.7082821883792005e-20 W / m2
# Region  51
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  52
# continuum flux :  3.143482505562497e-18 W / m2
# Predicted continuum :  3.928703941339548e-18 W / m2
# line flux :  2.1845092219258463e-19 W / m2
# Region  53
# continuum flux :  2.3871390064831197e-18 W / m2
# Predicted continuum :  3.022895328952033e-18 W / m2
# line flux :  1.0555201612753481e-19 W / m2
# Region  54
# continuum flux :  3.4440990386865575e-19 W / m2
# Predicted continuum :  4.398943304162211e-19 W / m2
# line flux :  9.390928918655902e-20 W / m2
# Region  55
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  56
# continuum flux :  1.8059124603262133e-19 W / m2
# Predicted continuum :  2.39013665415424e-19 W / m2
# line flux :  1.371588127352418e-20 W / m2
# Region  57
# continuum flux :  2.262171040409898e-19 W / m2
# Predicted continuum :  3.105821473112443e-19 W / m2
# line flux :  6.280469900235947e-21 W / m2
# Region  58
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  59
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  60
# continuum flux :  1.777305333711938e-19 W / m2
# Predicted continuum :  2.3335044891543073e-19 W / m2
# line flux :  2.935605393321828e-20 W / m2
# Region  61
# continuum flux :  1.2864100272113433e-19 W / m2
# Predicted continuum :  1.7391536612348364e-19 W / m2
# line flux :  3.864168239038597e-20 W / m2
# Region  62
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  63
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  64
# continuum flux :  1.9777278202493426e-19 W / m2
# Predicted continuum :  2.5797844528808136e-19 W / m2
# line flux :  6.200280063626155e-21 W / m2
# Region  65
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  66
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  67
# continuum flux :  1.47697580219173e-19 W / m2
# Predicted continuum :  1.943297806088741e-19 W / m2
# line flux :  1.1266362436440296e-19 W / m2
# Region  68
# continuum flux :  1.8730005298149613e-19 W / m2
# Predicted continuum :  2.384469004032766e-19 W / m2
# line flux :  1.073844028922484e-19 W / m2
# Region  69
# continuum flux :  1.503099730689409e-19 W / m2
# Predicted continuum :  2.0149705002521356e-19 W / m2
# line flux :  4.123227533260326e-21 W / m2
# Region  70
# continuum flux :  nan W / m2
# Predicted continuum :  1.540078804349661e-19 W / m2
# line flux :  nan W / m2
# Region  71
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  72
# continuum flux :  nan W / m2
# Predicted continuum :  1.8801699398308857e-19 W / m2
# line flux :  nan W / m2
# Region  73
# continuum flux :  1.3288695249721494e-19 W / m2
# Predicted continuum :  1.7721518888041494e-19 W / m2
# line flux :  2.2808366168054096e-20 W / m2
# Region  74
# continuum flux :  1.561505241539057e-19 W / m2
# Predicted continuum :  1.9788341924435575e-19 W / m2
# line flux :  3.229997660521185e-20 W / m2
# Region  75
# continuum flux :  1.5723472354457308e-19 W / m2
# Predicted continuum :  2.0784570126691582e-19 W / m2
# line flux :  1.5349728498109863e-20 W / m2
# Region  76
# continuum flux :  2.27304019605937e-19 W / m2
# Predicted continuum :  2.841482905341718e-19 W / m2
# line flux :  1.1664762858866392e-20 W / m2
# Region  77
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  78
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  79
# continuum flux :  1.4931040775410304e-19 W / m2
# Predicted continuum :  1.9058506590227956e-19 W / m2
# line flux :  2.922380410854837e-20 W / m2
# Region  80
# continuum flux :  1.1343475325040195e-19 W / m2
# Predicted continuum :  1.475305660725615e-19 W / m2
# line flux :  4.3697592444610186e-20 W / m2
# Region  81
# continuum flux :  2.144135605662391e-19 W / m2
# Predicted continuum :  2.5612317486402864e-19 W / m2
# line flux :  1.0563513323010126e-20 W / m2
# Region  82
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  83
# continuum flux :  1.1796152910915822e-19 W / m2
# Predicted continuum :  1.602027545706563e-19 W / m2
# line flux :  3.513986448925302e-20 W / m2
# Region  84
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  85
# continuum flux :  1.881735297328627e-19 W / m2
# Predicted continuum :  2.3040516996655783e-19 W / m2
# line flux :  4.7837745930250825e-20 W / m2
# Region  86
# continuum flux :  1.1605484016442267e-19 W / m2
# Predicted continuum :  1.5259695451104983e-19 W / m2
# line flux :  4.674069946287409e-20 W / m2
# Region  87
# continuum flux :  1.8465571030804974e-19 W / m2
# Predicted continuum :  2.473259357206826e-19 W / m2
# line flux :  2.115291381477492e-19 W / m2
# Region  88
# continuum flux :  2.8798326293987385e-19 W / m2
# Predicted continuum :  3.6737318056854886e-19 W / m2
# line flux :  4.849467393946396e-19 W / m2
# Region  89
# continuum flux :  1.120532089492349e-19 W / m2
# Predicted continuum :  1.4777857158360873e-19 W / m2
# line flux :  7.239896295307997e-22 W / m2
# Region  90
# continuum flux :  1.341000190083356e-19 W / m2
# Predicted continuum :  1.763074534207554e-19 W / m2
# line flux :  3.257186358942008e-20 W / m2
# Region  91
# continuum flux :  1.0809596050595121e-19 W / m2
# Predicted continuum :  1.3537095348080688e-19 W / m2
# line flux :  -1.3323736245985075e-20 W / m2
# Region  92
# continuum flux :  9.571752548030593e-20 W / m2
# Predicted continuum :  1.3227405420330886e-19 W / m2
# line flux :  2.1911192893702785e-20 W / m2
# Region  93
# continuum flux :  1.140705647731535e-19 W / m2
# Predicted continuum :  1.4538924551564768e-19 W / m2
# line flux :  4.6304254918221705e-21 W / m2
# Region  94
# continuum flux :  2.489321477569573e-19 W / m2
# Predicted continuum :  3.4047772715762226e-19 W / m2
# line flux :  -2.2456843601193822e-20 W / m2
# Region  95
# continuum flux :  1.7999494600482374e-19 W / m2
# Predicted continuum :  2.3048835112095857e-19 W / m2
# line flux :  2.980149819672281e-20 W / m2
# Region  96
# continuum flux :  5.229535220043306e-19 W / m2
# Predicted continuum :  7.214288947918144e-19 W / m2
# line flux :  8.570666315251755e-22 W / m2
# Region  97
# continuum flux :  1.1669061529440335e-19 W / m2
# Predicted continuum :  1.6448295702835185e-19 W / m2
# line flux :  2.1055418681588776e-20 W / m2
# Region  98
# continuum flux :  1.0000892083286404e-19 W / m2
# Predicted continuum :  1.3667212793689636e-19 W / m2
# line flux :  6.1567336307205304e-21 W / m2
# Region  99
# continuum flux :  1.2903258607847537e-19 W / m2
# Predicted continuum :  1.7467824624693098e-19 W / m2
# line flux :  1.2677132563433345e-20 W / m2
# Region  100
# continuum flux :  2.798586389978777e-19 W / m2
# Predicted continuum :  3.5870328870601827e-19 W / m2
# line flux :  -1.048711696958508e-21 W / m2
# Region  101
# continuum flux :  3.1589235601893148e-19 W / m2
# Predicted continuum :  4.443973260801759e-19 W / m2
# line flux :  2.663141709261385e-20 W / m2
# Region  102
# continuum flux :  1.953834180410864e-19 W / m2
# Predicted continuum :  2.672634862772243e-19 W / m2
# line flux :  2.1072394410767708e-20 W / m2
# Region  103
# continuum flux :  3.51106518250047e-19 W / m2
# Predicted continuum :  4.7016699946720635e-19 W / m2
# line flux :  3.1765250530771253e-20 W / m2
# Region  104
# continuum flux :  2.238290838037922e-19 W / m2
# Predicted continuum :  3.1580788145599614e-19 W / m2
# line flux :  -1.2236707935914299e-20 W / m2
# Region  105
# continuum flux :  1.6706261308769223e-19 W / m2
# Predicted continuum :  2.3170329443510097e-19 W / m2
# line flux :  -3.1503618083148836e-21 W / m2
# Region  106
# continuum flux :  2.3452846118203647e-19 W / m2
# Predicted continuum :  3.2486203144310587e-19 W / m2
# line flux :  2.6842951820086688e-20 W / m2
# Region  107
# continuum flux :  4.212060297600159e-19 W / m2
# Predicted continuum :  5.573729001635361e-19 W / m2
# line flux :  3.5023633150092986e-20 W / m2
# Region  108
# continuum flux :  2.699373374503085e-19 W / m2
# Predicted continuum :  3.726242029673021e-19 W / m2
# line flux :  1.491065252039107e-20 W / m2
# Region  109
# continuum flux :  5.197729679501761e-19 W / m2
# Predicted continuum :  6.750768242946316e-19 W / m2
# line flux :  3.0780435994297525e-20 W / m2
# Region  110
# continuum flux :  5.158288138232258e-19 W / m2
# Predicted continuum :  6.730439381928254e-19 W / m2
# line flux :  5.434197675230804e-20 W / m2
# Region  111
# continuum flux :  2.774297109425364e-19 W / m2
# Predicted continuum :  3.7748824158783308e-19 W / m2
# line flux :  4.716934957701167e-20 W / m2
# Region  112
# continuum flux :  5.195812671521465e-19 W / m2
# Predicted continuum :  6.806455176615956e-19 W / m2
# line flux :  5.480444964077613e-20 W / m2
# Region  113
# continuum flux :  7.005700400547408e-19 W / m2
# Predicted continuum :  9.041841476528976e-19 W / m2
# line flux :  4.921751789464272e-20 W / m2
# Region  114
# continuum flux :  2.8411994277081775e-19 W / m2
# Predicted continuum :  3.846889034887455e-19 W / m2
# line flux :  4.06177084664019e-20 W / m2
# Region  115
# continuum flux :  2.712436710085479e-19 W / m2
# Predicted continuum :  3.6490596106914275e-19 W / m2
# line flux :  2.165390108644887e-20 W / m2
# Region  116
# continuum flux :  4.218543422922131e-19 W / m2
# Predicted continuum :  5.720111155736394e-19 W / m2
# line flux :  3.515010548331624e-20 W / m2
# Region  117
# continuum flux :  2.8101028600645794e-19 W / m2
# Predicted continuum :  3.681141396335158e-19 W / m2
# line flux :  -1.123305640826483e-20 W / m2
# Region  118
# continuum flux :  9.964102475302265e-19 W / m2
# Predicted continuum :  1.2812500466983123e-18 W / m2
# line flux :  3.306619843086309e-20 W / m2
# Region  119
# continuum flux :  5.011165837471831e-19 W / m2
# Predicted continuum :  6.506214889265365e-19 W / m2
# line flux :  4.637450852226983e-20 W / m2
# Region  120
# continuum flux :  2.3558823346331976e-19 W / m2
# Predicted continuum :  3.210729838915999e-19 W / m2
# line flux :  1.799724041812581e-20 W / m2
# Region  121
# continuum flux :  6.497102129639559e-19 W / m2
# Predicted continuum :  8.369533906525723e-19 W / m2
# line flux :  2.6719008160922535e-20 W / m2
# Region  122
# continuum flux :  6.333853436460807e-19 W / m2
# Predicted continuum :  8.216134282807817e-19 W / m2
# line flux :  3.2495328179185866e-20 W / m2
# Region  123
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  124
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  125
# continuum flux :  5.174334280226667e-19 W / m2
# Predicted continuum :  7.083897119944675e-19 W / m2
# line flux :  4.973446379579021e-20 W / m2
# Region  126
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  127
# continuum flux :  5.82407545993504e-19 W / m2
# Predicted continuum :  7.847549481220243e-19 W / m2
# line flux :  5.1398230663078306e-20 W / m2
# Region  128
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  129
# continuum flux :  6.328486221599174e-19 W / m2
# Predicted continuum :  8.102371443461018e-19 W / m2
# line flux :  2.6879955061890995e-20 W / m2
# Region  130
# continuum flux :  3.410153950082284e-19 W / m2
# Predicted continuum :  4.479105489930538e-19 W / m2
# line flux :  2.3074430907236116e-20 W / m2
# Region  131
# continuum flux :  9.32812770687664e-19 W / m2
# Predicted continuum :  1.178002904709983e-18 W / m2
# line flux :  3.577302150099168e-20 W / m2
# Region  132
# continuum flux :  3.663249055015853e-19 W / m2
# Predicted continuum :  4.950016494227821e-19 W / m2
# line flux :  4.144276409307078e-20 W / m2
# Region  133
# continuum flux :  4.1255806019473517e-19 W / m2
# Predicted continuum :  5.546564247256759e-19 W / m2
# line flux :  2.8240620056599426e-20 W / m2
# Region  134
# continuum flux :  4.456316804454168e-19 W / m2
# Predicted continuum :  5.802911632480914e-19 W / m2
# line flux :  3.513491184690519e-20 W / m2
# Region  135
# continuum flux :  3.7953892704109236e-19 W / m2
# Predicted continuum :  5.008288630657553e-19 W / m2
# line flux :  1.167305860996323e-20 W / m2
# Region  136
# continuum flux :  4.1248197121382197e-19 W / m2
# Predicted continuum :  5.566584177584697e-19 W / m2
# line flux :  3.0055536636568925e-20 W / m2
# Region  137
# continuum flux :  3.0037530535477046e-19 W / m2
# Predicted continuum :  3.952043174047844e-19 W / m2
# line flux :  2.655198701753043e-20 W / m2
# Region  138
# continuum flux :  3.9752023100467577e-19 W / m2
# Predicted continuum :  5.462908649012905e-19 W / m2
# line flux :  3.374025774523868e-20 W / m2
# Region  139
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  140
# continuum flux :  1.5826387555381514e-19 W / m2
# Predicted continuum :  2.1186820518603797e-19 W / m2
# line flux :  -1.3727454397983023e-21 W / m2
# Region  141
# continuum flux :  1.9950334656053223e-19 W / m2
# Predicted continuum :  2.556703369086747e-19 W / m2
# line flux :  8.501341400876015e-21 W / m2
# Region  142
# continuum flux :  2.8934274781395314e-19 W / m2
# Predicted continuum :  3.7999518162082935e-19 W / m2
# line flux :  1.576419072448196e-20 W / m2
# Region  143
# continuum flux :  1.996332749047498e-19 W / m2
# Predicted continuum :  2.5407851323400427e-19 W / m2
# line flux :  1.2448089399346515e-19 W / m2
# Region  144
# continuum flux :  nan W / m2
# Predicted continuum :  1.6388586429002408e-19 W / m2
# line flux :  nan W / m2
# Region  145
# continuum flux :  1.1755190332671701e-19 W / m2
# Predicted continuum :  1.634558916753985e-19 W / m2
# line flux :  1.088715018282824e-20 W / m2
# Region  146
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  147
# continuum flux :  1.0490857864166452e-19 W / m2
# Predicted continuum :  1.3028669676577556e-19 W / m2
# line flux :  1.312529739834999e-19 W / m2
# Region  148
# continuum flux :  7.638621513976376e-20 W / m2
# Predicted continuum :  1.0611366216809283e-19 W / m2
# line flux :  6.606200849854539e-20 W / m2
# Region  149
# continuum flux :  1.1253898489606503e-19 W / m2
# Predicted continuum :  1.4834546120256605e-19 W / m2
# line flux :  4.916791366447387e-19 W / m2
# Region  150
# continuum flux :  1.031769545444682e-19 W / m2
# Predicted continuum :  1.4251267065032707e-19 W / m2
# line flux :  1.736667991763239e-19 W / m2
# Region  151
# continuum flux :  8.732550252064638e-20 W / m2
# Predicted continuum :  1.2773438928551003e-19 W / m2
# line flux :  8.227656979778566e-20 W / m2
# Region  152
# continuum flux :  1.6343014034871466e-19 W / m2
# Predicted continuum :  2.1069811222885255e-19 W / m2
# line flux :  5.675723328103928e-20 W / m2
# Region  153
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  154
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  155
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  156
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  157
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  158
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  159
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  160
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  161
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  162
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  163
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  164
# continuum flux :  2.0300670431723985e-19 W / m2
# Predicted continuum :  2.7578861206925154e-19 W / m2
# line flux :  5.803101089360144e-20 W / m2
# Region  165
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  166
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  167
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  168
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  169
# continuum flux :  9.831325674183805e-20 W / m2
# Predicted continuum :  1.3252206548653204e-19 W / m2
# line flux :  2.3225941296685713e-19 W / m2
# Region  170
# continuum flux :  9.179965080965982e-20 W / m2
# Predicted continuum :  1.1765486390733665e-19 W / m2
# line flux :  2.1546233127783591e-19 W / m2
# Region  171
# continuum flux :  nan W / m2
# Predicted continuum :  nan W / m2
# line flux :  nan W / m2
# Region  172
# continuum flux :  nan W / m2
# Predicted continuum :  1.991199775480517e-19 W / m2
# line flux :  nan W / m2

# %%
test['files']
# Out:
# {'F187N_continuum': '/d/crow2/phangs/cycle3/ngc1433_paa_native_anchor_cont.fits',
#  'F187N_line': '/d/crow2/phangs/cycle3/ngc1433_paa_native_anchor_line.fits',
#  'F150W': '/d/crow2/phangs/cycle3/ngc1433_nircam_lv3_f150w_i2d_anchor.fits',
#  'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1433_nircam_lv3_f300m_i2d_anchor.fits'}

# %%
full_data

# %%
show_images([data['ic5332']['F300M']], loc, 1*u.arcsec)

# %%
print(kiana_files[0])
print(kiana_files[1])
# Out:
# Data_files/Kiana_files/ic5332_HST_Ha_all_clusters_results.csv
# Data_files/Kiana_files/ic5332_HST_Ha_nircam_all_clusters_results.csv

# %%
# Out:
# array(['Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f115w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f140m.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f150w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f164n.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f182m.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f187n.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f200w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f210m.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f212n.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f250m.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f300m.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f335m.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f360m.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f405n.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f430m.fits',
#        'Data_files/Image_files/v0p3/ngc5194_nircam_lv3_f444w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_miri_lv3_f560w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_miri_lv3_f770w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_miri_lv3_f1000w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_miri_lv3_f1130w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_miri_lv3_f1280w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_miri_lv3_f1500w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_miri_lv3_f1800w.fits',
#        'Data_files/Image_files/v0p3/ngc5194_miri_lv3_f2100w.fits'],
#       dtype='<U57')

# %%
t = Table.read(kiana_files[1], format="csv")
t['best.sfh.age']
# Out:
# <Column name='best.sfh.age' dtype='float64' length=166>
#  53.0
#  76.0
#   4.0
#   4.0
#   7.0
#   8.0
#   6.0
#   6.0
#   4.0
# 110.0
# 110.0
# 102.0
#   ...
#   2.0
#   3.0
#   4.0
#   3.0
#   3.0
#   1.0
#   1.0
#   1.0
#   5.0
#   3.0
#   1.0

# %%
danny_files = glob.glob('/d/crow2/phangs/cycle*/**/*', recursive=True)
danny_files
# Out:
# ['/d/crow2/phangs/cycle2/pa-alpha',
#  '/d/crow2/phangs/cycle2/v0p1p14',
#  '/d/crow2/phangs/cycle2/v0p1p15',
#  '/d/crow2/phangs/cycle2/v0p1p16',
#  '/d/crow2/phangs/cycle2/v0p2p0',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ic5273_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ic5273_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1068_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1068_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1097_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1097_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1511_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1511_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1546_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1546_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1559_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1559_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1637_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1637_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1792_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1792_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1808_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1808_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1809_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc1809_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2090_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2090_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2283_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2283_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2775_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2775_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2903_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2903_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2997_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc2997_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3059_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3059_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3137_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3137_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3239_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3239_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3344_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3344_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3507_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3507_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3511_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3511_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3521_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3521_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3596_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3596_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3621_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc3621_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4298_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4298_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4424_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4424_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4457_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4457_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4540_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4540_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4548_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4548_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4569_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4569_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4571_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4571_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4654_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4654_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4694_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4694_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4781_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4781_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4826_combined_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4826_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4826_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4941_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4941_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4951_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc4951_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc5042_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc5042_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc5248_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc5248_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc7456_Pa_cont.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/ngc7456_Pa_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p1p14/README',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/rclone.command.txt',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ic1954_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ic5273_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc0685_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc1511_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc1546_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc1809_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc1559_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc2090_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc2283_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc2775_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3059_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3137_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3239_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3344_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3368_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3507_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3511_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3521_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3596_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3621_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4424_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4457_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4540_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4569_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4571_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4654_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4694_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4781_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4941_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4951_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc5042_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc7456_f187n_line.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ic1954_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ic5273_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc0685_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc1511_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc1546_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc1559_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc1809_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc2090_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc2283_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc2775_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3059_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3137_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3239_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3344_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3368_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3507_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3511_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3521_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3596_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc3621_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4424_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4457_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4540_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4569_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4571_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4654_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4694_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4781_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4941_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc4951_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc5042_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/ngc7456_f187n_continuum.fits',
#  '/d/crow2/phangs/cycle2/pa-alpha/v0p2p0/README',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3239_miri_lv3_f2100w_bgr_segm.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3239_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3239_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3239_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3239_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3344_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3344_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3344_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3344_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3344_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3596_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3596_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3596_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3596_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3596_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3621_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3621_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3621_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3621_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3621_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3626_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3626_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3626_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3626_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3626_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4424_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4424_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4424_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4424_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4424_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4457_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4457_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4457_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4457_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4457_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4496a_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4496a_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4496a_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4496a_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4496a_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4536_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4536_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4536_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4536_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4536_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4540_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4540_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4540_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4540_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4540_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4548_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4548_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4548_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4548_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4548_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4571_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4571_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4571_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4571_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4571_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4579_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4579_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4579_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4579_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4579_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4731_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4731_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4731_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4731_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4731_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4781_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4781_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4781_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4781_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4781_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4826_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4826_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4826_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4826_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4826_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4941_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4941_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4941_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4941_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4941_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5042_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5042_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5042_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5042_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5042_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5134_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5134_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5134_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5134_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5134_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5248_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5248_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5248_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5248_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc5248_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3137_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3137_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3137_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3137_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3137_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3521_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3521_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3521_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3521_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3521_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2775_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2775_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2775_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2775_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2775_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3511_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3511_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3511_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3511_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3511_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2997_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2997_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2997_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2997_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2997_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4298_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4298_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4298_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4298_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4298_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2566_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2566_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2566_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2566_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2566_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2903_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2903_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2903_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2903_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2903_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3059_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3059_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3059_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3059_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3059_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3507_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3507_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3507_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3507_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc3507_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4569_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4569_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4569_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4569_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4569_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ic5273_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ic5273_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ic5273_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ic5273_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ic5273_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1097_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1097_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1097_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1097_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1097_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1511_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1511_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1511_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1511_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1511_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1546_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1546_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1546_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1546_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1546_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1559_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1559_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1559_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1559_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1559_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1637_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1637_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1637_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1637_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1637_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1792_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1792_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1792_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1792_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1792_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1808_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1808_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1808_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1808_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1808_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1809_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1809_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1809_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1809_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc1809_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2090_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2090_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2090_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2090_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2090_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2283_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2283_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2283_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2283_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc2283_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4654_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4654_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4654_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4654_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4654_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4689_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4689_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4689_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4689_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4689_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc7456_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc7456_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc7456_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc7456_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc7456_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4951_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4951_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4951_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4951_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4951_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4694_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4694_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4694_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4694_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/ngc4694_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p14/f300m_diagnostic_plots.tar',
#  '/d/crow2/phangs/cycle2/v0p1p14/f300m_diagnostic_plots',
#  '/d/crow2/phangs/cycle2/v0p1p14/anchoring_diagnostic_plots.tar',
#  '/d/crow2/phangs/cycle2/v0p1p14/anchoring_diagnostic_plots',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1097',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1511',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1546',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1559',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1637',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1792',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1808',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1809',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2090',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2283',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2566',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2775',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2903',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2997',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3059',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3137',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3239',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3344',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3507',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3511',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3521',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3596',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3621',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3626',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4298',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4424',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4457',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4496a',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4536',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4540',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4548',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4569',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4571',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4579',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4654',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4689',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4694',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4731',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4781',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4826',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4941',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4951',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc5042',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc5134',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc5248',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc5643',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc6300',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc7456',
#  '/d/crow2/phangs/cycle2/v0p1p15/ic5273',
#  '/d/crow2/phangs/cycle2/v0p1p15/rclone.command.txt',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1097/ngc1097_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1097/ngc1097_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1097/ngc1097_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1097/ngc1097_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1097/ngc1097_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1097/ngc1097_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1511/ngc1511_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1511/ngc1511_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1511/ngc1511_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1511/ngc1511_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1511/ngc1511_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1511/ngc1511_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1546/ngc1546_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1546/ngc1546_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1546/ngc1546_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1546/ngc1546_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1546/ngc1546_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1546/ngc1546_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1559/ngc1559_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1559/ngc1559_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1559/ngc1559_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1559/ngc1559_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1559/ngc1559_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1559/ngc1559_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1637/ngc1637_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1637/ngc1637_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1637/ngc1637_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1637/ngc1637_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1637/ngc1637_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1637/ngc1637_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1792/ngc1792_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1792/ngc1792_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1792/ngc1792_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1792/ngc1792_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1792/ngc1792_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1792/ngc1792_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1808/ngc1808_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1808/ngc1808_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1808/ngc1808_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1808/ngc1808_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1808/ngc1808_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1808/ngc1808_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1809/ngc1809_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1809/ngc1809_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1809/ngc1809_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1809/ngc1809_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1809/ngc1809_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc1809/ngc1809_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2090/ngc2090_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2090/ngc2090_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2090/ngc2090_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2090/ngc2090_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2090/ngc2090_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2090/ngc2090_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2283/ngc2283_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2283/ngc2283_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2283/ngc2283_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2283/ngc2283_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2283/ngc2283_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2283/ngc2283_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2566/ngc2566_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2566/ngc2566_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2566/ngc2566_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2566/ngc2566_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2566/ngc2566_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2566/ngc2566_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2775/ngc2775_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2775/ngc2775_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2775/ngc2775_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2775/ngc2775_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2775/ngc2775_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2775/ngc2775_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2903/ngc2903_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2903/ngc2903_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2903/ngc2903_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2903/ngc2903_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2903/ngc2903_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2903/ngc2903_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2997/ngc2997_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2997/ngc2997_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2997/ngc2997_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2997/ngc2997_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2997/ngc2997_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc2997/ngc2997_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3059/ngc3059_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3059/ngc3059_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3059/ngc3059_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3059/ngc3059_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3059/ngc3059_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3059/ngc3059_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3137/ngc3137_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3137/ngc3137_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3137/ngc3137_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3137/ngc3137_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3137/ngc3137_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3137/ngc3137_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3239/ngc3239_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3239/ngc3239_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3239/ngc3239_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3239/ngc3239_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3239/ngc3239_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3239/ngc3239_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3344/ngc3344_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3344/ngc3344_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3344/ngc3344_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3344/ngc3344_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3344/ngc3344_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3344/ngc3344_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3507/ngc3507_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3507/ngc3507_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3507/ngc3507_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3507/ngc3507_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3507/ngc3507_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3507/ngc3507_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3511/ngc3511_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3511/ngc3511_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3511/ngc3511_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3511/ngc3511_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3511/ngc3511_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3511/ngc3511_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3521/ngc3521_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3521/ngc3521_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3521/ngc3521_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3521/ngc3521_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3521/ngc3521_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3521/ngc3521_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3596/ngc3596_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3596/ngc3596_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3596/ngc3596_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3596/ngc3596_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3596/ngc3596_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3596/ngc3596_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3621/ngc3621_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3621/ngc3621_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3621/ngc3621_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3621/ngc3621_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3621/ngc3621_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3621/ngc3621_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3626/ngc3626_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3626/ngc3626_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3626/ngc3626_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3626/ngc3626_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3626/ngc3626_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc3626/ngc3626_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4298/ngc4298_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4298/ngc4298_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4298/ngc4298_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4298/ngc4298_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4298/ngc4298_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4298/ngc4298_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4424/ngc4424_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4424/ngc4424_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4424/ngc4424_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4424/ngc4424_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4424/ngc4424_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4424/ngc4424_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4457/ngc4457_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4457/ngc4457_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4457/ngc4457_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4457/ngc4457_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4457/ngc4457_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4457/ngc4457_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4496a/ngc4496a_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4496a/ngc4496a_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4496a/ngc4496a_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4496a/ngc4496a_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4496a/ngc4496a_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4496a/ngc4496a_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4536/ngc4536_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4536/ngc4536_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4536/ngc4536_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4536/ngc4536_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4536/ngc4536_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4536/ngc4536_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4540/ngc4540_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4540/ngc4540_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4540/ngc4540_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4540/ngc4540_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4540/ngc4540_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4540/ngc4540_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4548/ngc4548_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4548/ngc4548_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4548/ngc4548_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4548/ngc4548_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4548/ngc4548_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4548/ngc4548_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4569/ngc4569_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4569/ngc4569_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4569/ngc4569_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4569/ngc4569_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4569/ngc4569_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4569/ngc4569_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4571/ngc4571_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4571/ngc4571_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4571/ngc4571_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4571/ngc4571_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4571/ngc4571_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4571/ngc4571_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4579/ngc4579_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4579/ngc4579_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4579/ngc4579_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4579/ngc4579_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4579/ngc4579_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4579/ngc4579_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4654/ngc4654_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4654/ngc4654_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4654/ngc4654_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4654/ngc4654_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4654/ngc4654_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4654/ngc4654_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4689/ngc4689_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p15/ngc4689/ngc4689_miri_lv3_f770w_i2d_anchor.fits',
# ...
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2775/ngc2775_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2775/ngc2775_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2775/ngc2775_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2775/ngc2775_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2775/ngc2775_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1637/ngc1637_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1637/ngc1637_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1637/ngc1637_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1637/ngc1637_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1637/ngc1637_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1637/ngc1637_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1809/ngc1809_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1809/ngc1809_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1809/ngc1809_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1809/ngc1809_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1809/ngc1809_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc1809/ngc1809_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2903/ngc2903_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2903/ngc2903_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2903/ngc2903_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2903/ngc2903_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2903/ngc2903_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2903/ngc2903_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2997/ngc2997_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2997/ngc2997_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2997/ngc2997_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2997/ngc2997_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2997/ngc2997_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc2997/ngc2997_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3239/ngc3239_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3239/ngc3239_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3239/ngc3239_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3239/ngc3239_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3239/ngc3239_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3239/ngc3239_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3059/ngc3059_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3059/ngc3059_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3059/ngc3059_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3059/ngc3059_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3059/ngc3059_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3059/ngc3059_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3511/ngc3511_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3511/ngc3511_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3511/ngc3511_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3511/ngc3511_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3511/ngc3511_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3511/ngc3511_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3521/ngc3521_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3521/ngc3521_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3521/ngc3521_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3521/ngc3521_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3521/ngc3521_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3521/ngc3521_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3596/ngc3596_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3596/ngc3596_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3596/ngc3596_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3596/ngc3596_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3596/ngc3596_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3596/ngc3596_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3626/ngc3626_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3626/ngc3626_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3626/ngc3626_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3626/ngc3626_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3626/ngc3626_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3626/ngc3626_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4496a/ngc4496a_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4496a/ngc4496a_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4496a/ngc4496a_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4496a/ngc4496a_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4496a/ngc4496a_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4496a/ngc4496a_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3621/ngc3621_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3621/ngc3621_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3621/ngc3621_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3621/ngc3621_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3621/ngc3621_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc3621/ngc3621_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4457/ngc4457_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4457/ngc4457_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4457/ngc4457_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4457/ngc4457_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4457/ngc4457_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4457/ngc4457_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4536/ngc4536_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4536/ngc4536_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4536/ngc4536_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4536/ngc4536_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4536/ngc4536_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4536/ngc4536_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4548/ngc4548_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4548/ngc4548_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4540/ngc4540_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4540/ngc4540_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4540/ngc4540_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4540/ngc4540_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4540/ngc4540_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4540/ngc4540_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4571/ngc4571_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4571/ngc4571_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4571/ngc4571_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4571/ngc4571_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4571/ngc4571_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4571/ngc4571_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4579/ngc4579_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4579/ngc4579_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4579/ngc4579_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4579/ngc4579_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4579/ngc4579_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4579/ngc4579_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4654/ngc4654_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4654/ngc4654_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4654/ngc4654_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4654/ngc4654_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4654/ngc4654_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4654/ngc4654_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4689/ngc4689_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4689/ngc4689_nircam_lv3_f200w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4689/ngc4689_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4689/ngc4689_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4689/ngc4689_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4689/ngc4689_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4694/ngc4694_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4694/ngc4694_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4694/ngc4694_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4694/ngc4694_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4694/ngc4694_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4694/ngc4694_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4781/ngc4781_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4781/ngc4781_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4781/ngc4781_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4781/ngc4781_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4781/ngc4781_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4781/ngc4781_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4951/ngc4951_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4951/ngc4951_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4951/ngc4951_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4951/ngc4951_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4951/ngc4951_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc4951/ngc4951_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5042/ngc5042_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5042/ngc5042_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5042/ngc5042_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5042/ngc5042_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5042/ngc5042_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5042/ngc5042_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5248/ngc5248_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5248/ngc5248_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5248/ngc5248_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5248/ngc5248_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5248/ngc5248_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5248/ngc5248_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5643/ngc5643_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5643/ngc5643_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5643/ngc5643_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5643/ngc5643_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5643/ngc5643_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc5643/ngc5643_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc7456/ngc7456_miri_lv3_f2100w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc7456/ngc7456_nircam_lv3_f150w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc7456/ngc7456_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc7456/ngc7456_nircam_lv3_f187n_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc7456/ngc7456_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p1p16/ngc7456/ngc7456_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle2/v0p2p0/rclone.command.txt',
#  '/d/crow2/phangs/cycle3/rclone.command.txt',
#  '/d/crow2/phangs/cycle3/ngc1097_paa_native_anchor_cont.fits',
#  '/d/crow2/phangs/cycle3/ngc1097_paa_native_anchor_line.fits',
#  '/d/crow2/phangs/cycle3/ngc1433_paa_native_anchor_cont.fits',
#  '/d/crow2/phangs/cycle3/ngc1433_paa_native_anchor_line.fits',
#  '/d/crow2/phangs/cycle3/ngc1512_paa_native_anchor_cont.fits',
#  '/d/crow2/phangs/cycle3/ngc1512_paa_native_anchor_line.fits',
#  '/d/crow2/phangs/cycle3/ngc1637_paa_native_anchor_cont.fits',
#  '/d/crow2/phangs/cycle3/ngc1637_paa_native_anchor_line.fits',
#  '/d/crow2/phangs/cycle3/ngc1672_paa_native_anchor_cont.fits',
#  '/d/crow2/phangs/cycle3/ngc1672_paa_native_anchor_line.fits',
#  '/d/crow2/phangs/cycle3/ngc1792_paa_native_anchor_cont.fits',
#  '/d/crow2/phangs/cycle3/ngc1792_paa_native_anchor_line.fits',
#  '/d/crow2/phangs/cycle3/ngc4826_paa_native_anchor_cont.fits',
#  '/d/crow2/phangs/cycle3/ngc4826_paa_native_anchor_line.fits',
#  '/d/crow2/phangs/cycle3/ngc6300_paa_native_anchor_cont.fits',
#  '/d/crow2/phangs/cycle3/ngc6300_paa_native_anchor_line.fits',
#  '/d/crow2/phangs/cycle3/README.md',
#  '/d/crow2/phangs/cycle1/v1p0p1',
#  '/d/crow2/phangs/cycle1/v1p1',
#  '/d/crow2/phangs/cycle1/v1p0p1/ic5332_miri_lv3_f1130w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ic5332_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ic5332_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ic5332_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ic5332_nircam_lv3_f360m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc0628_miri_lv3_f1130w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc0628_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc0628_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc0628_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc0628_nircam_lv3_f360m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc1087_miri_lv3_f1130w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc1087_miri_lv3_f770w_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc1087_nircam_lv3_f300m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc1087_nircam_lv3_f335m_i2d_anchor.fits',
#  '/d/crow2/phangs/cycle1/v1p0p1/ngc1087_nircam_lv3_f360m_i2d_anchor.fits',
#  ...]

# %%
data
# Out:
# {'ic5332': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ic5332_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc628c': {},
#  'ngc628e': {},
#  'ngc1087': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1087_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc1300': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1300_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc1365': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1365_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc1385': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1385_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc1433': {'F187N_continuum': '/d/crow2/phangs/cycle3/ngc1433_paa_native_anchor_cont.fits',
#   'F187N_line': '/d/crow2/phangs/cycle3/ngc1433_paa_native_anchor_line.fits',
#   'F150W': '/d/crow2/phangs/cycle3/ngc1433_nircam_lv3_f150w_i2d_anchor.fits',
#   'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1433_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc1512': {'F187N_continuum': '/d/crow2/phangs/cycle3/ngc1512_paa_native_anchor_cont.fits',
#   'F187N_line': '/d/crow2/phangs/cycle3/ngc1512_paa_native_anchor_line.fits',
#   'F150W': '/d/crow2/phangs/cycle3/ngc1512_nircam_lv3_f150w_i2d_anchor.fits',
#   'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1512_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc1566': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1566_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc1672': {'F187N_continuum': '/d/crow2/phangs/cycle3/ngc1672_paa_native_anchor_cont.fits',
#   'F187N_line': '/d/crow2/phangs/cycle3/ngc1672_paa_native_anchor_line.fits',
#   'F150W': '/d/crow2/phangs/cycle3/ngc1672_nircam_lv3_f150w_i2d_anchor.fits',
#   'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1672_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc3351': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc3351_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc3627': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc3627_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc4254': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc4254_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc4303': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc4303_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc4321': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc4321_nircam_lv3_f300m_i2d_anchor.fits'},
#  'ngc7496': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc7496_nircam_lv3_f300m_i2d_anchor.fits'}}

# %%
data
# Out:
# {'ic5332': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ic5332_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc628c': {'files': {}},
#  'ngc628e': {'files': {}},
#  'ngc1087': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1087_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc1300': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1300_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc1365': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1365_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc1433': {'files': {'F187N_continuum': '/d/crow2/phangs/cycle3/ngc1433_paa_native_anchor_cont.fits',
#    'F187N_line': '/d/crow2/phangs/cycle3/ngc1433_paa_native_anchor_line.fits',
#    'F150W': '/d/crow2/phangs/cycle3/ngc1433_nircam_lv3_f150w_i2d_anchor.fits',
#    'F187N': '/d/crow2/phangs/cycle3/ngc1433_nircam_lv3_f187n_i2d_anchor.fits',
#    'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1433_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc1512': {'files': {'F187N_continuum': '/d/crow2/phangs/cycle3/ngc1512_paa_native_anchor_cont.fits',
#    'F187N_line': '/d/crow2/phangs/cycle3/ngc1512_paa_native_anchor_line.fits',
#    'F150W': '/d/crow2/phangs/cycle3/ngc1512_nircam_lv3_f150w_i2d_anchor.fits',
#    'F187N': '/d/crow2/phangs/cycle3/ngc1512_nircam_lv3_f187n_i2d_anchor.fits',
#    'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1512_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc1566': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1566_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc1672': {'files': {'F187N_continuum': '/d/crow2/phangs/cycle3/ngc1672_paa_native_anchor_cont.fits',
#    'F187N_line': '/d/crow2/phangs/cycle3/ngc1672_paa_native_anchor_line.fits',
#    'F150W': '/d/crow2/phangs/cycle3/ngc1672_nircam_lv3_f150w_i2d_anchor.fits',
#    'F187N': '/d/crow2/phangs/cycle3/ngc1672_nircam_lv3_f187n_i2d_anchor.fits',
#    'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1672_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc3351': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc3351_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc3627': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc3627_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc4254': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc4254_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc4303': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc4303_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc4321': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc4321_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc7496': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc7496_nircam_lv3_f300m_i2d_anchor.fits'}},
#  'ngc1385': {'files': {'F300M': '/d/crow2/phangs/cycle1/v1p1/ngc1385_nircam_lv3_f300m_i2d_anchor.fits'}}}

# %%
file = glob.glob('/d/crow2/phangs/cycle*/**/*')
for f in file:
    if 'ngc628' in f:
        print(f)

# %%
kiana_files[:2]
# Out:
# ['Data_files/Kiana_files/ic5332_HST_Ha_all_clusters_results.csv',
#  'Data_files/Kiana_files/ic5332_HST_Ha_nircam_all_clusters_results.csv']

# %%
t = Table.read(kiana_files[0])
t[:5]
# Out:
# <Table length=5>
#  col0 bayes.attenuation.A550 ...        dec                 EW_658
# int64        float64         ...      float64              float64
# ----- ---------------------- ... ------------------ ----------------------
#     0      0.063556351426262 ... -36.11846645690033 -6.299754114352955e-09
#     1    0.23875536752787987 ... -36.11832429409832 -3.397202391686293e-09
#     2    0.03747427328233481 ... -36.11766298784988 -2.502491352090883e-09
#     3    0.03912593475526506 ... -36.11757283640979 -3.850445744693641e-08
#     4    0.08808123483998243 ... -36.11733108013675 -8.957504348066007e-09

# %%
t = Table.read(kiana_files[1])
t[:5]
# Out:
# WARNING: OverflowError converting to FloatType in column bayes.stellar.m_gas_old, possibly resulting in degraded precision. [astropy.io.ascii.fastbasic]
# WARNING: OverflowError converting to FloatType in column bayes.stellar.m_star_old, possibly resulting in degraded precision. [astropy.io.ascii.fastbasic]
# <Table length=5>
#  col0 bayes.attenuation.A550 ...        dec                 EW_658
# int64        float64         ...      float64              float64
# ----- ---------------------- ... ------------------ ----------------------
#     0    0.01391347757469584 ... -36.11846645690033 -6.299754114352955e-09
#     1  0.0021928156369607444 ... -36.11832429409832 -3.397202391686293e-09
#     2 4.0449167298388543e-10 ... -36.11766298784988 -2.502491352090883e-09
#     3   0.004536651095562939 ... -36.11757283640979 -3.850445744693641e-08
#     4  0.0002560185413446976 ... -36.11733108013675 -8.957504348066007e-09

# %%
file = '/d/crow1/tools/cigale/database_builder/filters/jwst/nircam/F300M.dat'
data = np.genfromtxt(file)
for line in data:
    print(line[0], line[1])
# Out:
# 27011.1 0.000103927
# 27024.6 0.000107417
# 27038.1 0.000112416
# 27051.7 0.000118399
# 27065.2 0.000124955
# 27078.7 0.000129533
# 27092.2 0.000135358
# 27105.7 0.000140734
# 27119.2 0.00015072
# 27132.7 0.00015911
# 27146.2 0.000164392
# 27159.8 0.000171301
# 27173.3 0.000181434
# 27186.8 0.000192534
# 27200.3 0.000201899
# 27213.8 0.000214611
# 27227.3 0.000227721
# 27240.8 0.000241396
# 27254.3 0.000255687
# 27267.9 0.000268673
# 27281.4 0.000286485
# 27294.9 0.000307932
# 27308.4 0.000330437
# 27321.9 0.000354781
# 27335.4 0.000379699
# 27348.9 0.000407978
# 27362.4 0.000444412
# 27375.9 0.000476524
# 27389.5 0.000516087
# 27403.0 0.000562366
# 27416.5 0.000615465
# 27430.0 0.000671417
# 27443.5 0.000731596
# 27457.0 0.000800597
# 27470.5 0.000878055
# 27484.0 0.000963636
# 27497.6 0.00105425
# 27511.1 0.00115705
# 27524.6 0.00126693
# 27538.1 0.00138531
# 27551.6 0.0015237
# 27565.1 0.00167028
# 27578.6 0.00182847
# 27592.1 0.00200202
# 27605.7 0.00219329
# 27619.2 0.00239798
# 27632.7 0.00261972
# 27646.2 0.00286029
# 27659.7 0.00312166
# 27673.2 0.0033995
# 27686.7 0.00369805
# 27700.2 0.00401836
# 27713.8 0.00435818
# 27727.3 0.00472278
# 27740.8 0.00510971
# 27754.3 0.00552118
# 27767.8 0.00597017
# 27781.3 0.00645151
# 27794.8 0.00697031
# 27808.3 0.0075178
# 27821.9 0.008113
# 27835.4 0.00875584
# 27848.9 0.00945329
# 27862.4 0.0102024
# 27875.9 0.0110326
# 27889.4 0.0119367
# 27902.9 0.012924
# 27916.4 0.0140086
# 27930.0 0.0152151
# 27943.5 0.0165424
# 27957.0 0.0180075
# 27970.5 0.0196521
# 27984.0 0.0214945
# 27997.5 0.0235402
# 28011.0 0.0258194
# 28024.5 0.0283812
# 28038.1 0.0312492
# 28051.6 0.0344205
# 28065.1 0.0380276
# 28078.6 0.0420808
# 28092.1 0.0466241
# 28105.6 0.0516807
# 28119.1 0.0573945
# 28132.6 0.0637841
# 28146.2 0.0708714
# 28159.7 0.0787623
# 28173.2 0.0875271
# 28186.7 0.0972674
# 28200.2 0.107774
# 28213.7 0.119246
# 28227.2 0.131611
# 28240.7 0.144815
# 28254.2 0.158782
# 28267.8 0.173364
# 28281.3 0.188404
# 28294.8 0.203736
# 28308.3 0.219156
# 28321.8 0.2344
# 28335.3 0.249294
# 28348.8 0.263679
# 28362.3 0.277337
# 28375.9 0.289923
# 28389.4 0.301861
# 28402.9 0.312966
# 28416.4 0.323299
# 28429.9 0.332369
# 28443.4 0.340544
# 28456.9 0.347895
# 28470.4 0.354449
# 28484.0 0.360217
# 28497.5 0.365351
# 28511.0 0.369664
# 28524.5 0.373391
# 28538.0 0.376637
# 28551.5 0.379438
# 28565.0 0.38185
# 28578.5 0.383869
# 28592.1 0.385587
# 28605.6 0.386826
# 28619.1 0.387912
# 28632.6 0.388974
# 28646.1 0.39009
# 28659.6 0.390932
# 28673.1 0.391433
# 28686.6 0.391799
# 28700.2 0.392058
# 28713.7 0.392255
# 28727.2 0.392372
# 28740.7 0.392412
# 28754.2 0.392392
# 28767.7 0.392349
# 28781.2 0.39227
# 28794.7 0.392187
# 28808.3 0.39208
# 28821.8 0.391973
# 28835.3 0.39186
# 28848.8 0.391745
# 28862.3 0.39119
# 28875.8 0.391108
# 28889.3 0.391033
# 28902.8 0.390983
# 28916.4 0.391026
# 28929.9 0.391512
# 28943.4 0.391568
# 28956.9 0.391625
# 28970.4 0.391667
# 28983.9 0.391694
# 28997.4 0.391708
# 29010.9 0.391618
# 29024.5 0.391488
# 29038.0 0.391331
# 29051.5 0.391167
# 29065.0 0.390976
# 29078.5 0.390751
# 29092.0 0.390503
# 29105.5 0.390003
# 29119.0 0.389586
# 29132.5 0.389349
# 29146.1 0.38911
# 29159.6 0.388855
# 29173.1 0.388578
# 29186.6 0.388303
# 29200.1 0.388024
# 29213.6 0.387593
# 29227.1 0.387158
# 29240.6 0.386719
# 29254.2 0.386275
# 29267.7 0.386166
# 29281.2 0.385837
# 29294.7 0.385409
# 29308.2 0.384926
# 29321.7 0.384389
# 29335.2 0.383859
# 29348.7 0.383325
# 29362.3 0.382789
# 29375.8 0.381993
# 29389.3 0.381265
# 29402.8 0.380753
# 29416.3 0.380279
# 29429.8 0.379803
# 29443.3 0.379776
# 29456.8 0.37929
# 29470.4 0.378805
# 29483.9 0.378314
# 29497.4 0.377817
# 29510.9 0.377584
# 29524.4 0.376939
# 29537.9 0.37629
# 29551.4 0.375657
# 29564.9 0.375027
# 29578.5 0.374412
# 29592.0 0.373816
# 29605.5 0.373232
# 29619.0 0.372669
# 29632.5 0.372127
# 29646.0 0.371617
# 29659.5 0.371137
# 29673.0 0.3707
# 29686.6 0.370279
# 29700.1 0.369889
# 29713.6 0.369565
# 29727.1 0.369282
# 29740.6 0.369042
# 29754.1 0.369183
# 29767.6 0.369513
# 29781.1 0.369358
# 29794.7 0.369234
# 29808.2 0.369001
# 29821.7 0.368707
# 29835.2 0.368432
# 29848.7 0.368174
# 29862.2 0.367921
# 29875.7 0.36767
# 29889.2 0.367782
# 29902.8 0.367592
# 29916.3 0.367504
# 29929.8 0.367404
# 29943.3 0.367298
# 29956.8 0.367164
# 29970.3 0.367017
# 29983.8 0.366846
# 29997.3 0.366651
# 30010.9 0.366244
# 30024.4 0.366077
# 30037.9 0.365543
# 30051.4 0.364972
# 30064.9 0.36459
# 30078.4 0.364183
# 30091.9 0.363538
# 30105.4 0.362977
# 30118.9 0.362574
# 30132.5 0.362148
# 30146.0 0.361701
# 30159.5 0.361234
# 30173.0 0.360763
# 30186.5 0.360275
# 30200.0 0.359774
# 30213.5 0.359084
# 30227.0 0.358389
# 30240.6 0.357685
# 30254.1 0.356966
# 30267.6 0.356241
# 30281.1 0.355501
# 30294.6 0.354763
# 30308.1 0.35423
# 30321.6 0.353833
# 30335.1 0.353416
# 30348.7 0.352993
# 30362.2 0.352643
# 30375.7 0.352521
# 30389.2 0.352054
# 30402.7 0.351622
# 30416.2 0.351366
# 30429.7 0.351095
# 30443.2 0.350808
# 30456.8 0.350504
# 30470.3 0.350187
# 30483.8 0.349994
# 30497.3 0.349883
# 30510.8 0.349426
# 30524.3 0.348937
# 30537.8 0.348441
# 30551.3 0.347948
# 30564.9 0.347455
# 30578.4 0.346972
# 30591.9 0.346496
# 30605.4 0.346202
# 30618.9 0.346166
# 30632.4 0.346155
# 30645.9 0.346165
# 30659.4 0.346595
# 30673.0 0.346684
# 30686.5 0.34703
# 30700.0 0.347291
# 30713.5 0.347205
# 30727.0 0.347142
# 30740.5 0.347108
# 30754.0 0.347107
# 30767.5 0.347127
# 30781.1 0.34717
# 30794.6 0.347236
# 30808.1 0.347531
# 30821.6 0.347975
# 30835.1 0.348421
# 30848.6 0.348869
# 30862.1 0.349316
# 30875.6 0.349753
# 30889.2 0.350175
# 30902.7 0.350595
# 30916.2 0.35109
# 30929.7 0.351551
# 30943.2 0.35241
# 30956.7 0.352815
# 30970.2 0.353194
# 30983.7 0.353538
# 30997.2 0.353863
# 31010.8 0.354012
# 31024.3 0.35411
# 31037.8 0.3542
# 31051.3 0.354285
# 31064.8 0.354372
# 31078.3 0.354477
# 31091.8 0.354589
# 31105.3 0.354777
# 31118.9 0.355064
# 31132.4 0.355387
# 31145.9 0.355738
# 31159.4 0.356118
# 31172.9 0.356521
# 31186.4 0.356927
# 31199.9 0.357308
# 31213.4 0.358377
# 31227.0 0.358935
# 31240.5 0.359387
# 31254.0 0.359647
# 31267.5 0.359679
# 31281.0 0.359387
# 31294.5 0.358687
# 31308.0 0.357453
# 31321.5 0.355517
# 31335.1 0.352952
# 31348.6 0.349552
# 31362.1 0.345315
# 31375.6 0.340136
# 31389.1 0.333909
# 31402.6 0.326755
# 31416.1 0.318495
# 31429.6 0.309314
# 31443.2 0.299088
# 31456.7 0.287991
# 31470.2 0.276147
# 31483.7 0.263876
# 31497.2 0.250886
# 31510.7 0.237466
# 31524.2 0.223937
# 31537.7 0.210421
# 31551.3 0.197043
# 31564.8 0.18401
# 31578.3 0.171335
# 31591.8 0.1592
# 31605.3 0.147634
# 31618.8 0.136689
# 31632.3 0.126423
# 31645.8 0.116823
# 31659.4 0.107906
# 31672.9 0.0996518
# 31686.4 0.0920358
# 31699.9 0.0850223
# 31713.4 0.0786384
# 31726.9 0.0728404
# 31740.4 0.0674977
# 31753.9 0.0625869
# 31767.5 0.058092
# 31781.0 0.0539893
# 31794.5 0.0502361
# 31808.0 0.0467924
# 31821.5 0.0436405
# 31835.0 0.0407534
# 31848.5 0.0381148
# 31862.0 0.035695
# 31875.5 0.0334741
# 31889.1 0.031439
# 31902.6 0.0295649
# 31916.1 0.0278418
# 31929.6 0.0262567
# 31943.1 0.0247915
# 31956.6 0.0234411
# 31970.1 0.0221938
# 31983.6 0.0210581
# 31997.2 0.0199803
# 32010.7 0.0189774
# 32024.2 0.0180445
# 32037.7 0.0171773
# 32051.2 0.0163669
# 32064.7 0.0156066
# 32078.2 0.0148929
# 32091.7 0.0142218
# 32105.3 0.0135945
# 32118.8 0.0130039
# 32132.3 0.0124287
# 32145.8 0.0119009
# 32159.3 0.0114007
# 32172.8 0.0109241
# 32186.3 0.0104718
# 32199.8 0.0100413
# 32213.4 0.00963467
# 32226.9 0.00924588
# 32240.4 0.00886485
# 32253.9 0.00849936
# 32267.4 0.00814925
# 32280.9 0.00781174
# 32294.4 0.00748799
# 32307.9 0.00717189
# 32321.5 0.00686612
# 32335.0 0.00657305
# 32348.5 0.00628778
# 32362.0 0.00601051
# 32375.5 0.00573778
# 32389.0 0.00547095
# 32402.5 0.00521406
# 32416.0 0.0049655
# 32429.6 0.00472488
# 32443.1 0.00449188
# 32456.6 0.00426677
# 32470.1 0.00404754
# 32483.6 0.00383463
# 32497.1 0.00362664
# 32510.6 0.00342668
# 32524.1 0.00323524
# 32537.7 0.00305313
# 32551.2 0.00288021
# 32564.7 0.0027108
# 32578.2 0.0025451
# 32591.7 0.00238818
# 32605.2 0.002239
# 32618.7 0.00209949
# 32632.2 0.00196805
# 32645.8 0.00183885
# 32659.3 0.00171324
# 32672.8 0.00159698
# 32686.3 0.00148865
# 32699.8 0.00138507
# 32713.3 0.00128865
# 32726.8 0.00119984
# 32740.3 0.00111488
# 32753.9 0.00103375
# 32767.4 0.000960298
# 32780.9 0.000891998
# 32794.4 0.000825952
# 32807.9 0.000765286
# 32821.4 0.000710412
# 32834.9 0.000656633
# 32848.4 0.000606797
# 32861.9 0.000562426
# 32875.5 0.00052076
# 32889.0 0.000480869
# 32902.5 0.000444852
# 32916.0 0.000411013
# 32929.5 0.000378836
# 32943.0 0.000350033
# 32956.5 0.000323669
# 32970.0 0.000298025
# 32983.6 0.000275006
# 32997.1 0.000255879
# 33010.6 0.000236213
# 33024.1 0.000218331
# 33037.6 0.000203084
# 33051.1 0.000186819
# 33064.6 0.000170678
# 33078.1 0.000156107
# 33091.7 0.000144751
# 33105.2 0.00013445
# 33118.7 0.000123392
# 33132.2 0.000112813
# 33145.7 0.000104914
