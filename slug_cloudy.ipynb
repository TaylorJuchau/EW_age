# %%
import numpy as np
import matplotlib.pyplot as plt
import sys
sys.path.append('/project/galaxies/tjuchau/software/Slug/slug2')
sys.path.append("/project/galaxies/tjuchau/software/Cloudy/c25.00/source/cloudy.exe")
import os

from Functions import *

import glob
import re
slug_path = "/project/galaxies/tjuchau/software/Slug/slug2/bin/slug"
cloudy_path = "/project/galaxies/tjuchau/software/Cloudy/c25.00/source/cloudy.exe"
import slugpy
wd = '/project/galaxies/tjuchau'
slug_output_dir = '/project/galaxies/tjuchau/data_files/misc_data/slug_outputs/'
os.chdir('/project/galaxies/tjuchau/projects/EW_vs_Age/modeling_files')
import shutil
import pandas as pd
import subprocess
import json

# -------------------------------
# Paths
# -------------------------------
cloudy_output_dir = "/project/galaxies/tjuchau/data_files/misc_data/cloudy_outputs"


os.system(f'''cloudy_slug.py [--cloudypath {cloudy_path}]
[-cm]
[-cf 0.5] [-d] [-hd 10000] [-ip 0.001]
[-ip0 IONPARAM0] [-ipm 0.1]
[--ionparammin 0.0001] [-nl NICELEVEL]
[-n NPROC] [-ps warn] [-r0 R0]
[-r1 R1] [-s]
[--slugpath {slug_path}] [-t {cloudy_output_dir}] [-v]
testing_shocks_5000''')

# %%
os.system(f'''python /project/galaxies/tjuchau/software/Slug/slug2/cloudy_slug/cloudy_slug.py [-h]''')

# %%
os.system('pwd')
